# %%
# pip install langchain
# pip install langchain_community
# pip install langchain_ollama

# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="qwen2.5:latest")

# %%
result = llm.invoke("who build you")

# %%
print(result.content)
# Out:
# I was developed by Alibaba Cloud, specifically as part of the Qwen project. My full name is Qwen-1001, and I'm designed to assist with a wide range of tasks, from generating human-like text to providing information and helping with creative writing. If you have any specific questions or need assistance with something, feel free to ask!

# %%
result = llm.invoke("how are you?")

# %%
print(result.content)
# Out:
# I'm just a digital entity here to help you! How can I assist you today?
